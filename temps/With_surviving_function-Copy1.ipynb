# %% [markdown]
# # RRQ Claim Project

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#RRQ-Claim-Project" data-toc-modified-id="RRQ-Claim-Project-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>RRQ Claim Project</a></span><ul class="toc-item"><li><span><a href="#Regression-output" data-toc-modified-id="Regression-output-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Regression output</a></span><ul class="toc-item"><li><span><a href="#Import-regression-outputs-for-the-5-specifications,-from-csv-to-df" data-toc-modified-id="Import-regression-outputs-for-the-5-specifications,-from-csv-to-df-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Import regression outputs for the 5 specifications, from csv to df</a></span></li><li><span><a href="#Variables-definition" data-toc-modified-id="Variables-definition-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Variables definition</a></span></li><li><span><a href="#We-only-want-to-keep-the-model-with-the-least-variables-(model-1)" data-toc-modified-id="We-only-want-to-keep-the-model-with-the-least-variables-(model-1)-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>We only want to keep the model with the least variables (model 1)</a></span></li><li><span><a href="#Generate-hazard-function-for-each-age-claim-and-cohort" data-toc-modified-id="Generate-hazard-function-for-each-age-claim-and-cohort-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Generate hazard function for each age claim and cohort</a></span></li><li><span><a href="#Change-the-previous-table-which-had-the-hazard-rate-saved-as-a-list-to-a-dataframe-that-has-the-hazard-rate-saved-as-a-column-with-all-characteristics-used-in-computing" data-toc-modified-id="Change-the-previous-table-which-had-the-hazard-rate-saved-as-a-list-to-a-dataframe-that-has-the-hazard-rate-saved-as-a-column-with-all-characteristics-used-in-computing-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Change the previous table which had the hazard rate saved as a list to a dataframe that has the hazard rate saved as a column with all characteristics used in computing</a></span></li><li><span><a href="#$h_t$-gor-a-given-set-of-parameters-or-itendity-(60-to-110-years-old)" data-toc-modified-id="$h_t$-gor-a-given-set-of-parameters-or-itendity-(60-to-110-years-old)-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>$h_t$ gor a given set of parameters or itendity (60 to 110 years old)</a></span></li></ul></li><li><span><a href="#Present-Value" data-toc-modified-id="Present-Value-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Present Value</a></span><ul class="toc-item"><li><span><a href="#Definition" data-toc-modified-id="Definition-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Definition</a></span></li><li><span><a href="#The-Gompertz-mortality-law-can-be-represented-as:" data-toc-modified-id="The-Gompertz-mortality-law-can-be-represented-as:-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>The Gompertz mortality law can be represented as:</a></span></li><li><span><a href="#In-stata" data-toc-modified-id="In-stata-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>In stata</a></span></li></ul></li><li><span><a href="#Reduction-for-clamming-before-normal-age" data-toc-modified-id="Reduction-for-clamming-before-normal-age-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Reduction for clamming before normal age</a></span><ul class="toc-item"><li><span><a href="#When-retirement-benefits-begin-before-age-65,-the-benefit-amount-is-reduced-by-0.6%-for-each-month-between-the-beginning-of-the-payments-and-the-65th-birthday.-Accordingly,-a-pensioner-who-is-entitled-to-the-maximum-benefit-will-have-the-benefit-amount-reduced-by-36%-if-he-or-she-decides-to-retire-at-60-years-of-age." data-toc-modified-id="When-retirement-benefits-begin-before-age-65,-the-benefit-amount-is-reduced-by-0.6%-for-each-month-between-the-beginning-of-the-payments-and-the-65th-birthday.-Accordingly,-a-pensioner-who-is-entitled-to-the-maximum-benefit-will-have-the-benefit-amount-reduced-by-36%-if-he-or-she-decides-to-retire-at-60-years-of-age.-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>When retirement benefits begin before age 65, the benefit amount is reduced by 0.6% for each month between the beginning of the payments and the 65th birthday. Accordingly, a pensioner who is entitled to the maximum benefit will have the benefit amount reduced by 36% if he or she decides to retire at 60 years of age.</a></span></li><li><span><a href="#Apply-reduction-rate-to-the-benefits-pays-at-65" data-toc-modified-id="Apply-reduction-rate-to-the-benefits-pays-at-65-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Apply reduction rate to the benefits pays at 65</a></span></li></ul></li><li><span><a href="#Comparison-of-2-PV" data-toc-modified-id="Comparison-of-2-PV-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Comparison of 2 PV</a></span></li><li><span><a href="#Progressive-annuity" data-toc-modified-id="Progressive-annuity-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Progressive annuity</a></span><ul class="toc-item"><li><span><a href="#Comparaison-function" data-toc-modified-id="Comparaison-function-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Comparaison function</a></span></li><li><span><a href="#Exemple-and-graph" data-toc-modified-id="Exemple-and-graph-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Exemple and graph</a></span></li><li><span><a href="#Interpretation" data-toc-modified-id="Interpretation-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Interpretation</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Regression output

# %% [markdown]
# ### Import regression outputs for the 5 specifications, from csv to df

# %%
import pandas as pd
import numpy as np
from itertools import product

df = pd.read_csv('../raw_data/output2_clean.csv', sep=',') #output2 is the sample without disability (N=307 055)

df2=df.transpose()
df2.columns = df2.iloc[0]
df2.drop(df2.index[0], inplace=True)
df=df2
df.index=df.index.str.replace('_t:','')
df.index=df.index.str.replace('/:','')
columns_to_convert = ['b1', 'b2', 'b3','b4','b5']  # Specify the columns you want to convert
for column in columns_to_convert:
    df[column] = df[column].astype(float)

# %% [markdown]
# ### Variables definition

# %% [markdown]
# | Variable | Description |
# |----------|-------------|
# | AC       | Age at which public pension is claimed. We consider ages 60 to 65. Reference at 65. |
# | Coh      | Birth cohorts in 5-year intervals: 1926, 1930, 1935, 1940, 1945, 1950 (to 1954). Reference at 1940. |
# | Dis_d    | Disability status, ages up to 65 (DSBCQI>0): 0 indicates no disability, 1 indicates claimed disability benefits. Reference at no disability. |
# | Sex      | Gender: 0 indicates women, 1 indicates men. Women as reference. |
# | Imm      | Immigrant dummy: 0 indicates non-immigrant, 1 indicates immigrant. Non-immigrant as reference. |
# | Mrt      | Marital status defined at AC: 0 indicates divorced/single, 1 indicates married, 2 indicates widowed. Divorced/single as reference. |
# | p_lvl    | Public pension level, defined in quintiles by year claimed & AC: 1 indicates lowest, 5 indicates highest. Reference at 3. |
# | pp_lvl   | Private pension level, defined in quintiles by birth year: 0 indicates no private pension, 1 indicates lowest, 5 indicates highest. Reference at 3. |

# %% [markdown]
# ### We only want to keep the model with the least variables (model 1)

# %%
model_1=pd.DataFrame({'Model1':df['b1']})
model_1 = model_1.dropna()
#the constant reports the baseline hazard, gamma is the gompertz parameter, other variables report hazard ratios

# %% [markdown]
# ### Generate hazard function for each age claim and cohort

# %%
def get_hazard(in_df, out_df):
    
    #extract the gamma and constant
    gamma = float(in_df.at['gamma','Model1'])
    cons = float(in_df.at['_cons','Model1'])

    #for each of our variable, 
    #extract the first characters of the index to know what level we are considering
    #extract the hazard ratio
    ac_values = [(index[:2], value) for index, value in in_df.loc[in_df.index.str.endswith('.AC'),'Model1'].items()]
    coh_values = [(index[:4], value) for index, value in in_df.loc[in_df.index.str.endswith('.coh'),'Model1'].items()]


    #define the age range we want to generate the hazard rate on
    t = np.arange(-5,46) #from 60 to 110

    #generate all possible combinations of values
    combinations = product(ac_values, coh_values)
    for ac, coh in combinations:
        #compute hazard rate
        fct = cons * ac[1] * coh[1] * np.exp(t * gamma)
        #compute survival rate
        st = np.exp((-1*(cons*ac[1]*coh[1])/gamma)*(np.exp(gamma*t)-1))
        #store the characteristics used in computing and the hazard and survival rate
        new_row = {'AC': ac[0], 'coh': coh[0],'t': t, 'ht': fct, 'st':st}
        #append stored estimates to the out dataframe
        out_df = out_df.append(new_row, ignore_index=True)
    return out_df

#initialize empty dataframe to receive out_df
hazard = pd.DataFrame(columns=['AC', 'coh', 't', 'ht', 'st'])
#run the function
hazard = get_hazard(model_1, hazard)
# Out:
# C:\Users\Xavier\AppData\Local\Temp\ipykernel_13180\3025856959.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   out_df = out_df.append(new_row, ignore_index=True)
# C:\Users\Xavier\AppData\Local\Temp\ipykernel_13180\3025856959.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   out_df = out_df.append(new_row, ignore_index=True)
# C:\Users\Xavier\AppData\Local\Temp\ipykernel_13180\3025856959.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   out_df = out_df.append(new_row, ignore_index=True)
# C:\Users\Xavier\AppData\Local\Temp\ipykernel_13180\3025856959.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ### Change the previous table which had the hazard rate saved as a list to a dataframe that has the hazard rate saved as a column with all characteristics used in computing

# %%
#initialize receiving df
table=pd.DataFrame()
#multiply all characteristics by 51 so that they are lists like the hazard rate
for var in ['AC','coh']:
    hazard[var] = hazard[var].apply(lambda x: [x] * 51)
    table[var]=hazard[var].explode()
#explode all series into a long form dataframe    
table['t'] = hazard['t'].explode()
table['ht'] = hazard['ht'].explode()
table['st'] = hazard['st'].explode()
table=table.reset_index()
#column identity serves to indicate separate combinations of characteristics used in computing hazard rate
table=table.rename(columns={'index':'identity'})
table.head(55)
# Out:
#     identity  AC   coh   t        ht        st
# 0          0  60  1926  -5  0.005216  1.035888
# 1          0  60  1926  -4  0.005853  1.030177
# 2          0  60  1926  -3  0.006567  1.023807
# 3          0  60  1926  -2  0.007367  1.016707
# 4          0  60  1926  -1  0.008266  1.008799
# 5          0  60  1926   0  0.009274       1.0
# 6          0  60  1926   1  0.010405  0.990219
# 7          0  60  1926   2  0.011675  0.979359
# 8          0  60  1926   3  0.013098  0.967316
# 9          0  60  1926   4  0.014696  0.953981
# 10         0  60  1926   5  0.016488  0.939238
# 11         0  60  1926   6    0.0185  0.922968
# 12         0  60  1926   7  0.020756  0.905048
# 13         0  60  1926   8  0.023287  0.885357
# 14         0  60  1926   9  0.026128  0.863773
# 15         0  60  1926  10  0.029314  0.840183
# 16         0  60  1926  11   0.03289  0.814482
# 17         0  60  1926  12  0.036901   0.78658
# 18         0  60  1926  13  0.041402  0.756412
# ...

# %% [markdown]
# ### $h_t$ gor a given set of parameters or itendity (60 to 110 years old)

# %% [markdown]
# Example for cohort born in 1926

# %%
ht_id1=table[table['AC']=='60']
ht_id1=ht_id1[ht_id1['coh']=='1926']
ht_id1= ht_id1.ht.values

# %%
ht_id2=table[table['AC']=='65']
ht_id2=ht_id2[ht_id2['coh']=='1926']
ht_id2= ht_id2.ht.values

# %% [markdown]
# ## Present Value

# %% [markdown]
# ### Definition

# %% [markdown]
# Let $T$ be curtate survival time and $Z$ be the present value of future annuity payments. Denote $v = \frac{1}{1+i}$ and let $B_t$ be the annuity amount to be paid at the end of year $t$.

# %% [markdown]
# $Z = \sum_{t=1}^{T} v^t \times B_t$

# %% [markdown]
# Then:
#
# $E(Z) = \sum_{t=1}^{w} v^{t-1} \cdot B_t \cdot (1 - q_t)$
#
# Were $w$ in te largest age in the Lifetable

# %%
def expected_present_value_future_annuity_payments(B, interest_rate, mortality_probabilities):
    """
    Calculate the expected present value of future annuity payments for annuity paid at the beginning of each year.

    Args:
    B (list of float): Annuity amount to be paid at the beginning of each year.
    interest_rate (float): The annual interest rate (expressed as a decimal).
    mortality_probabilities (list of float): Probability of dying in each year.

    Returns:
    float: The expected present value of future annuity payments.
    """
    v = 1 / (1 + interest_rate)
    expected_present_value = 0

    for t in range(len(B)):
        expected_present_value += v**(t) * B[t] * (1 - mortality_probabilities[t])

    return expected_present_value

# %%
# Example usage:
B = [0]*5 + [10000] * 46  # Annuity amount to be paid at the end of each year (e.g., for 51 years: 60 to 110 years old)
interest_rate = 0.03  # Annual interest rate (5%)
mortality_probabilities = ht_id2  # Probability of dying in each year, here the hazard of Gompertz

E_Z = expected_present_value_future_annuity_payments(B, interest_rate, mortality_probabilities)
print("Expected Present Value of Future Annuity Payments:", round(E_Z, 2))
# Out:
# Expected Present Value of Future Annuity Payments: 180959.03

# %% [markdown]
# ### The Gompertz mortality law can be represented as:
# the assumption is not implemented yet

# %% [markdown]
# $\mu(x) = \alpha e^{\beta x}$

# %% [markdown]
# where $\mu(x)$  is the mortality rate at age $x$, $\alpha$ is the baseline mortality rate, and $\beta$ is the rate of increase of mortality with age.

# %% [markdown]
# Note that since the Gompertz model is for a mortality hazard, we can integrate it
# to give us the the survival function:

# %% [markdown]
# $h(x) = \alpha e^{\beta x}$ , and

# %% [markdown]
# $S(x) = \exp \left( \frac{\alpha}{\beta} (1 - e^{-\beta x}) \right)$

# %% [markdown]
# ### In stata

# %% [markdown]
# $S(t)= \exp\left\{-\lambda_j \gamma^{-1} \left(e^{\gamma t_j} - 1\right)\right\}$,
#
# $\quad \lambda_j = \exp(x_j \beta)$
#
# $ h(t)=\lambda\exp(\gamma t) $

# %% [markdown]
# The model is implemented by parameterizing $\lambda_j = \exp(x_j \beta)$, implying that $h_0(t) = \exp(\gamma t)$, where $\gamma$ is an ancillary parameter to be estimated from the data.

# %% [markdown]
# ## Reduction for claiming before normal age

# %% [markdown]
# ### When retirement benefits begin before age 65, the benefit amount is reduced by 0.6% for each month between the beginning of the payments and the 65th birthday. Accordingly, a pensioner who is entitled to the maximum benefit will have the benefit amount reduced by 36% if he or she decides to retire at 60 years of age.

# %% [markdown]
# \begin{equation}
# \text{reduction_percent} = (65 - \text{retirement_age}) \times \text{reduction_rate} \times 12
# \end{equation}
#
# \begin{equation}
# \text{reduced_benefit} = \text{original_benefit} \times \left(1 - \frac{\text{reduction_percent}}{100}\right)
# \end{equation}

# %%
def calculate_reduced_benefit(original_benefit, retirement_age, reduction_rate=0.6):
    if retirement_age >= 65:
        return original_benefit  # No reduction if retirement age is 65 or older
    else:
        reduction_percent = (65 - retirement_age) * reduction_rate * 12 
        reduced_benefit = original_benefit * (1 - reduction_percent / 100)
        return reduced_benefit

# %% [markdown]
# ### Apply reduction rate to the benefits pays at 65

# %%
def apply_reduction_to_annuity(B, retirement_age, reduction_rate=0.6):
    return list(map(lambda amount: calculate_reduced_benefit(amount, retirement_age, reduction_rate), B))

# %%
# Example usage:
B = [10000]*51  # Annuity amount to be paid at the end of each year
retirement_age = 60
reduction_rate = 0.6

reduced_B = apply_reduction_to_annuity(B, retirement_age, reduction_rate)
print("Reduced Annuity Amounts:", reduced_B[0])
# Out:
# Reduced Annuity Amounts: 6400.0

# %%
# Example usage:
B= reduced_B  # Annuity amount to be paid at the end of each year (e.g., $10000 annually for 51 years: 60 to 110 years old)
interest_rate = 0.03  # Annual interest rate (5%)
mortality_probabilities = ht_id1  # Probability of dying in each year, here the hazard of Gompertz

E_Z = expected_present_value_future_annuity_payments(B, interest_rate, mortality_probabilities)
print("Expected Present Value of Future Annuity Payments:", round(E_Z, 2))
# Out:
# Expected Present Value of Future Annuity Payments: 142131.31

# %% [markdown]
# ## Comparison of 2 PV

# %%
def compare_expected_present_value_annuities(B1, B2, interest_rate, mortality_probabilities1, mortality_probabilities2):
    """
    Compare the expected present value of two series of annuities.

    Args:
    B1 (list of float): Annuity amounts for series 1.
    B2 (list of float): Annuity amounts for series 2.
    interest_rate (float): The annual interest rate (expressed as a decimal).
    mortality_probabilities1 (list of float): Probability of dying for series 1 in each year.
    mortality_probabilities2 (list of float): Probability of dying for series 2 in each year.

    Returns:
    tuple: A tuple containing the expected present value of series 1 and series 2.
    """
    pv1 = expected_present_value_future_annuity_payments(B1, interest_rate, mortality_probabilities1)
    pv2 = expected_present_value_future_annuity_payments(B2, interest_rate, mortality_probabilities2)
    return pv1, pv2

# %%
# Example usage:
B  = [10000]*51
B1 = [0]*5+[10000] * 46  # Annuity amounts for series 1
B2 = apply_reduction_to_annuity(B, retirement_age, reduction_rate)  # Annuity amounts for series 2
interest_rate = 0.03  # Annual interest rate (5%)
mortality_probabilities1 = ht_id2  # Probability of dying for series 1 in each year
mortality_probabilities2 = ht_id1  # Probability of dying for series 2 in each year

pv1, pv2 = compare_expected_present_value_annuities(B1, B2, interest_rate, mortality_probabilities1, mortality_probabilities2)
print("Expected Present Value of Series 1:", round(pv1, 2))
print("Expected Present Value of Series 2:", round(pv2, 2))

if pv1 > pv2:
    print("Series 1 has a higher expected present value.")
elif pv1 < pv2:
    print("Series 2 has a higher expected present value.")
else:
    print("Both series have the same expected present value.")
# Out:
# Expected Present Value of Series 1: 180959.03
# Expected Present Value of Series 2: 142131.31
# Series 1 has a higher expected present value.

# %% [markdown]
# ## Progressive annuity

# %%
def generate_progressive_annuity(initial_amount, growth_rate, periods):
    """
    Generate a progressive annuity for the first 10 years and remains constant afterward.

    Args:
    initial_amount (float): Initial annuity amount for the first year.
    growth_rate (float): Growth rate of the annuity amount for the first 10 years (expressed as a decimal).
    periods (int): Number of periods (years).

    Returns:
    list: A list containing the annuity amounts for each year.
    """
    annuity_schedule = []
    for t in range(1, periods + 1):
        if t <= 10:
            annuity_schedule.append(initial_amount * (1 + growth_rate) ** (t - 1))
        else:
            annuity_schedule.append(initial_amount * (1 + growth_rate) ** (10 - 1))
    return annuity_schedule

# %%
# Example usage:
initial_amount = 1000  # Initial annuity amount for the first year
growth_rate = 0.05  # Growth rate of the annuity amount for the first 10 years (5%)
periods = 51  # Number of periods (years)

annuity_schedule = generate_progressive_annuity(initial_amount, growth_rate, periods)
annuity_schedule[0:10]
# Out:
# [1000.0,
#  1050.0,
#  1102.5,
#  1157.6250000000002,
#  1215.5062500000001,
#  1276.2815625000003,
#  1340.0956406250004,
#  1407.1004226562504,
#  1477.455443789063,
#  1551.3282159785163]

# %% [markdown]
# ### Comparaison function

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_expected_present_value(initial_amounts, growth_rates, periods, interest_rate, mortality_probabilities):
    """
    Plot the expected present value of annuities for different initial amounts and growth rates.

    Args:
    initial_amounts (list of float): Initial annuity amounts for each scenario.
    growth_rates (list of float): Growth rates of the annuity amounts for each scenario (expressed as decimals).
    periods (int): Number of periods (years).
    interest_rate (float): The annual interest rate (expressed as a decimal).
    mortality_probabilities (list of float): Probability of dying for each year.

    Returns:
    None
    """
    grid_growth_rates = np.linspace(growth_rates[0], growth_rates[-1], 100)  # Generate a grid of growth rates

    plt.figure(figsize=(15, 8))
    for initial_amount in initial_amounts:
        expected_present_values = []
        for growth_rate in grid_growth_rates:
            annuity_schedule = generate_progressive_annuity(initial_amount, growth_rate, periods)
            expected_pv = expected_present_value_future_annuity_payments(annuity_schedule, interest_rate, mortality_probabilities)
            expected_present_values.append(expected_pv)

        plt.plot(grid_growth_rates*100, expected_present_values, label=f"Initial Amount at 60 : {initial_amount}")

    
    plt.axhline(y=141000, color='r', linestyle='--', label='Horizontal Line at 141K, PV of 6400 claim at 60')
    plt.axvline(x=3.4, color='gray')
    plt.axvline(x=4.9, color='gray')
    plt.xlabel('Growth Rate %')
    plt.ylabel('Present Value')
    plt.title('Present Value of Annuities for Different Initial Amounts and Growth Rates')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ### Exemple and graph

# %%
# Example usage:
initial_amounts = [4000, 4500, 5000, 5500]  # Initial annuity amounts for each scenario
growth_rates = [0.02, 0.06]  # Growth rates of the annuity amounts for each scenario (5%, 7%)
periods = 51  # Number of periods (years)
interest_rate = 0.03  # Annual interest rate (3%)
mortality_probabilities = ht_id1  # Probability of dying for each year (e.g., 0.01 annually for 51 years)

plot_expected_present_value(initial_amounts, growth_rates, periods, interest_rate, mortality_probabilities)

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Recevoir un montant 5 500 à 60 qui crois à un taux annuel de enviro 3,4% jusqu'à 69 à 6 755 et qui reste constant par la suite est équivalent à recevoir 6 400 à partir de 60 ans.

# %% [markdown]
# Recevoir un montant 4 500 à 60 qui crois à un taux annuel de enviro 4,9% jusqu'à 69 à 6 921 et qui reste constant par la suite est équivalent à recevoir 6 400 à partir de 60 ans.
